# %%
import seaborn as sns
import statsmodels.api as sm
import matplotlib.pyplot as plt
import re
from sklearn.ensemble import IsolationForest
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("C:/Users/Richard Edison/Downloads/bdd_espac_2016_csv/BASES DE DATOS ABIERTOS CVS/Bases Publicación ESPAC 2016_csv/Bases Publicación ESPAC 2016_csv/cpnac2016.csv", sep=',')
df_provin = pd.read_excel("C:/Users/Richard Edison/Downloads/provin.xlsx")
df
#
# Out:
#       provin  canton  parroq  cultivo  sup_planth  sup_cosechh  uso_ferti  \
# 0          1       1      57        1        3.30         3.30          1
# 1          1       1      57        1        2.80         2.80          1
# 2          1       1      57        1        2.30         2.30          1
# 3          1       1      57        1        4.29         4.29          1
# 4          1       1      57        1        4.00         4.00          2
# ...      ...     ...     ...      ...         ...          ...        ...
# 3787      90       4      51        1        3.00         3.00          1
# 3788      90       4      51        1       75.00        75.00          1
# 3789      90       4      51        1        1.50         1.00          2
# 3790      90       4      51        1        0.47         0.40          1
# 3791      90       4      51        1        1.00         0.75          2
#
#       q_cosech  q_venta    prod_tm   venta_tm  uso_riego  uso_plaguic  tasa
# ...

# %%
df_provin
# Out:
#       provin     credit
# 0          1    6585.80
# 1          1   10111.10
# 2          1   25809.60
# 3          1   14750.00
# 4          1    2888.30
# ...      ...        ...
# 1599      24    3900.62
# 1600      24    7813.36
# 1601      24   14650.00
# 1602      24    5860.02
# 1603      24  318000.00
#
# [1604 rows x 2 columns]

# %%
df_prov = pd.DataFrame(df_provin)
df_prov['provin'] = df_prov['provin'].astype(int)
prov = pd.merge(df, df_provin, how="left", on=["provin"])
prov
# Out:
#         provin  canton  parroq  cultivo  sup_planth  sup_cosechh  uso_ferti  \
# 0            1       1      57        1        3.30         3.30          1
# 1            1       1      57        1        3.30         3.30          1
# 2            1       1      57        1        3.30         3.30          1
# 3            1       1      57        1        3.30         3.30          1
# 4            1       1      57        1        3.30         3.30          1
# ...        ...     ...     ...      ...         ...          ...        ...
# 644451      90       4      51        1        3.00         3.00          1
# 644452      90       4      51        1       75.00        75.00          1
# 644453      90       4      51        1        1.50         1.00          2
# 644454      90       4      51        1        0.47         0.40          1
# 644455      90       4      51        1        1.00         0.75          2
#
# ...

# %%
df_cleaned = prov.dropna(subset=['credit'])
df_cleaned
# Out:
#         provin  canton  parroq  cultivo  sup_planth  sup_cosechh  uso_ferti  \
# 0            1       1      57        1         3.3          3.3          1
# 1            1       1      57        1         3.3          3.3          1
# 2            1       1      57        1         3.3          3.3          1
# 3            1       1      57        1         3.3          3.3          1
# 4            1       1      57        1         3.3          3.3          1
# ...        ...     ...     ...      ...         ...          ...        ...
# 644390      24       1      55        2         3.0          NaN          1
# 644391      24       1      55        2         3.0          NaN          1
# 644392      24       1      55        2         3.0          NaN          1
# 644393      24       1      55        2         3.0          NaN          1
# 644394      24       1      55        2         3.0          NaN          1
#
# ...

# %%
df_clean = df_cleaned.dropna(subset=['credit'])
df_clean
# Out:
#         provin  canton  parroq  cultivo  sup_planth  sup_cosechh  uso_ferti  \
# 0            1       1      57        1         3.3          3.3          1
# 1            1       1      57        1         3.3          3.3          1
# 2            1       1      57        1         3.3          3.3          1
# 3            1       1      57        1         3.3          3.3          1
# 4            1       1      57        1         3.3          3.3          1
# ...        ...     ...     ...      ...         ...          ...        ...
# 644390      24       1      55        2         3.0          NaN          1
# 644391      24       1      55        2         3.0          NaN          1
# 644392      24       1      55        2         3.0          NaN          1
# 644393      24       1      55        2         3.0          NaN          1
# 644394      24       1      55        2         3.0          NaN          1
#
# ...

# %%
df_clean.drop_duplicates(subset=['credit'], inplace=True)
df_clean
# Out:
#         provin  canton  parroq  cultivo  sup_planth  sup_cosechh  uso_ferti  \
# 0            1       1      57        1        3.30          3.3          1
# 1            1       1      57        1        3.30          3.3          1
# 2            1       1      57        1        3.30          3.3          1
# 3            1       1      57        1        3.30          3.3          1
# 4            1       1      57        1        3.30          3.3          1
# ...        ...     ...     ...      ...         ...          ...        ...
# 615657      23       1      50        1        0.49          NaN          2
# 615659      23       1      50        1        0.49          NaN          2
# 615660      23       1      50        1        0.49          NaN          2
# 615662      23       1      50        1        0.49          NaN          2
# 644364      24       1      52        2        2.00          2.0          2
#
# ...

# %%
import pandas as pd

# Supongamos que tienes un DataFrame llamado 'df' y quieres eliminar filas con valores nulos en la columna 'mi_columna'
prov.dropna(subset=['credit'], inplace=True)
prov
# Out:
#      provin  canton  parroq  cultivo  sup_planth  sup_cosechh  uso_ferti  \
# 0         1       1      57        1      3.3000       3.3000          1
# 1         1       1      57        1      2.8000       2.8000          1
# 2         1       1      57        1      2.3000       2.3000          1
# 3         1       1      57        1      4.2900       4.2900          1
# 4         1       1      57        1      4.0000       4.0000          2
# ..      ...     ...     ...      ...         ...          ...        ...
# 98        2       4      50        2      2.1168       2.1168          1
# 99        2       4      50        2      0.7056       0.7056          2
# 100       2       4      50        2      1.0000       1.0000          1
# 101       2       4      50        2      4.2336       4.2336          1
# 102       2       4      50        2      4.2336       4.2336          1
#
#      q_cosech  q_venta   prod_tm  venta_tm  uso_riego  uso_plaguic  tasa  \
# ...

# %%
# Supongamos que tienes un DataFrame llamado "mi_dataframe" con las variables modificadas
# Guarda el DataFrame en un nuevo archivo CSV
df_clean.to_csv("C:/Users/Richard Edison/Downloads/credit.cvs", index=False)
